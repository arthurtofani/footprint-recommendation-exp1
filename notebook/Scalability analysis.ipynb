# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# Summary file
summary_file = '/cache/dataset/sessions.md.csv/partials/summary.csv'
df = pd.read_csv(summary_file)
df.head(3)
# Out:
#    itr  build_time  match_time  amnt_docs  amnt_queries term_field  \
# 0    1     156.477      74.596       5147          1047      track
# 1    1     157.034      77.742       5147          1047      track
# 2    1       3.108       2.694        100            25      track
#
#   document_field  query_terms_ratio  memory_size  index_size_kb
# 0        session                0.8            1           2006
# 1        session                0.8            2           2512
# 2           user                0.8            1            102

# %%
# index size in kb
df['index_size_per_doc'] = df.index_size_kb / df.amnt_docs

# time in seconds
df['docs_insertion_per_second'] = df.amnt_docs / df.build_time
df['matches_per_second'] = df.amnt_queries / df.match_time
df.groupby(['document_field',  'memory_size']).mean()
# Out:
#                             itr  build_time  match_time  amnt_docs  \
# document_field memory_size
# session        1            1.0   152.61750    91.10325     5147.0
#                2            1.0   152.74875    92.55000     5147.0
#                3            1.0   154.95650    93.88375     5147.0
#                4            1.0   154.77975    93.78075     5147.0
#                5            1.0   155.03175    83.64700     5147.0
#                6            1.0   156.94075    87.60750     5147.0
#                7            1.0   158.59100    89.00350     5147.0
#                8            1.0   155.30725    89.28475     5147.0
# user           1            1.0     3.20750     2.07375      100.0
#                2            1.0     3.02050     2.05300      100.0
#                3            1.0     3.34950     1.74750      100.0
#                4            1.0     3.31750     1.70850      100.0
#                5            1.0     2.94450     1.98200      100.0
#                6            1.0     3.06350     1.91325      100.0
#                7            1.0     3.18575     1.81500      100.0
#                8            1.0     3.27600     1.72725      100.0
#
#                             amnt_queries  query_terms_ratio  index_size_kb  \
# document_field memory_size
# session        1                  1187.5              0.475        1983.50
#                2                  1187.5              0.475        2490.75
#                3                  1187.5              0.475        2657.50
#                4                  1187.5              0.475        2670.25
#                5                  1187.5              0.475        2633.75
#                6                  1187.5              0.475        2577.50
#                7                  1187.5              0.475        2447.25
#                8                  1187.5              0.475        2304.75
# user           1                    25.0              0.475         102.00
#                2                    25.0              0.475         117.00
#                3                    25.0              0.475          77.50
#                4                    25.0              0.475         118.25
#                5                    25.0              0.475         157.00
#                6                    25.0              0.475         165.00
#                7                    25.0              0.475         149.25
#                8                    25.0              0.475         170.25
#
#                             index_size_per_doc  docs_insertion_per_second  \
# document_field memory_size
# session        1                      0.385370                  33.744497
#                2                      0.483923                  33.714385
#                3                      0.516320                  33.242918
#                4                      0.518797                  33.259932
#                5                      0.511706                  33.220348
#                6                      0.500777                  32.813005
#                7                      0.475471                  32.457328
#                8                      0.447785                  33.166157
# user           1                      1.020000                  31.249733
#                2                      1.170000                  33.203280
#                3                      0.775000                  29.997804
#                4                      1.182500                  30.269725
#                5                      1.570000                  34.005913
#                6                      1.650000                  32.719572
#                7                      1.492500                  31.419398
#                8                      1.702500                  30.591650
#
#                             matches_per_second
# document_field memory_size
# session        1                     13.183971
#                2                     12.940662
#                3                     12.763423
#                4                     12.751152
#                5                     14.238289
#                6                     13.654539
#                7                     13.470230
#                8                     13.340741
# user           1                     12.423658
#                2                     12.329899
#                3                     15.575577
#                4                     15.358752
#                5                     12.897789
#                6                     13.416796
#                7                     14.897809
#                8                     15.403280
